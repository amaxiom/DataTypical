# %% [markdown]
# # DataTypical Test Suite

# %% [markdown]
# #### Author: Amanda S. Barnard

# %%
# %run -i DataTypical_unit_test_suite.py
# Out:
# ...
# DataTypical v0.7 - Unit Test Suite
# ...
#
# RUNNING UNIT TEST SUITE
#
# --------------------------------------------------------------------------------
# TEST 1: Shapley Correctness Tests
# --------------------------------------------------------------------------------
#
# [1.1] Testing Shapley additivity property...
#   [OK] Shapley values computed and reasonable
#   [OK] Additivity property verified (top samples have non-zero attribution)
#
# [1.2] Testing Shapley stability...
#   [OK] Shapley values are stable and reasonable for top samples
#
# --------------------------------------------------------------------------------
# TEST 2: Reproducibility Tests
# --------------------------------------------------------------------------------
#
# [2.1] Testing deterministic reproducibility...
#   [OK] 100% deterministic reproducibility confirmed
#
# [2.2] Testing different seeds produce variation...
#   [OK] Different seeds produce variation (rank diff: 0.000152)
#
# ...

# %%
# %run -i DataTypical_autodetection_test_suite.py
# Out:
# ...
# DataTypical v0.7 - Auto-Detection Test Suite
# ...
#
# RUNNING AUTO-DETECTION TEST SUITE
#
# --------------------------------------------------------------------------------
# TEST 1: Tabular Data - DataFrame
# --------------------------------------------------------------------------------
#
# [1a] Fitting with auto-detection...
#
# Fast mode defaults:
#   archetypal_method: nmf
#   shapley_n_permutations: 30
#   shapley_top_n: 0.5
#   shapley_compute_formative: False
# Auto-detected data_type: 'tabular'
#
# Fitting archetypal: NMF Approximation
#
# Fitting archetypes: NMF (k=6)
#   Stored: W =(100, 6), H =(6, 6), n_archetypes =6
#
# Fitting prototypes: Facility Location (k=20)
#   Selected 20 prototypes, knee at 1
#
# Stereotypical configuration:
#   Target column: 'ic50_nM'
#   Target value: 'min'
#   Column range: [0.10, 183.72]
#   Targeting samples with minimum ic50_nM
#   [OK] Detected data type: tabular
#
# [1b] Transforming...
#   [OK] Results shape: (100, 10)
# ...

# %%
# %run -i DataTypical_scaling_test_suite.py
# Out:
# ...
# DataTypical v0.7 - Performance and Scaling Test Suite
# ...
#
# RUNNING PERFORMANCE TEST SUITE
#
# Test data: 100 samples, 3 features
#
# --------------------------------------------------------------------------------
# TEST 1: fast_mode=True
# --------------------------------------------------------------------------------
# [OK] Completed in 1.16s
#   archetypal_method: nmf (expected: nmf)
#   shapley_n_permutations: 30 (expected: 30)
#   shapley_top_n: 0.5 (expected: 0.5)
#   shapley_compute_formative: False (expected: False)
#   Results shape: (100, 11)
#
# --------------------------------------------------------------------------------
# TEST 2: fast_mode=False
# --------------------------------------------------------------------------------
# [OK] Completed in 5.58s
#   archetypal_method: aa (expected: aa)
#   shapley_n_permutations: 100 (expected: 100)
#   shapley_top_n: None (expected: None)
#   shapley_compute_formative: True (expected: True)
#
# ...

# %%
# %run -i DataTypical_visualization_test_suite.py
# Out:
# ...
# DataTypical v0.7 - Visualization Test Suite
# ...
#
# RUNNING VISUALIZATION TEST SUITE
# [OK] Data prepared: 100 samples, 6 features
#
# --------------------------------------------------------------------------------
# TEST 1: significance_plot Tests
# --------------------------------------------------------------------------------
#
# [1.1] Basic significance plot
#   [OK] Basic plot created
#
# [1.2] Color by property
#   [OK] Color-coded plot created
#
# [1.3] Quadrant lines
#   [OK] Quadrant lines added
#
# [1.4] Invalid significance error handling
#   [OK] Correctly raised ValueError
#
# [1.5] All three significance types
#   [OK] All three types work
#
# -> Module 1: 5/5 tests passed
#
# --------------------------------------------------------------------------------
# TEST 2: heatmap Tests
# --------------------------------------------------------------------------------
#
# [2.1] Archetypal heatmap (actual ordering)
#   [OK] Archetypal heatmap created
#
# ...

# %%
# %run -i DataTypical_benchmark_test_suite.py
# Out:
# ...
# DataTypical v0.7 - Benchmark Suite
# ...
#
# RUNNING BENCHMARK SUITE
#
# --------------------------------------------------------------------------------
# BENCHMARK: 1. Small Tabular (Fast Mode)
# --------------------------------------------------------------------------------
# Dataset: 200 compounds, 7 features
# Mode: fast_mode=True (explanations, no formative)
#   [OK] Top archetypal: 0.6408
#   [OK] Explanations working (sum: 0.6460)
#   [OK] Formative correctly skipped (all None)
#
# PASSED in 3.60s
#
# --------------------------------------------------------------------------------
# BENCHMARK: 2. Medium Tabular (Publication Mode)
# --------------------------------------------------------------------------------
# Dataset: 300 molecules, 4 features
# Mode: fast_mode=False (full dual-perspective)
#   [OK] Archetypal range: [0.3599, 0.9265]
#   [OK] Formative range: [0.0000, 1.0000]
#   [OK] Formative attributions working
#
# PASSED in 5.91s
#
# ...
